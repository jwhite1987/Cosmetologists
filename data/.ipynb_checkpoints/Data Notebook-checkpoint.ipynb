# %%
import pandas as pd

# %%
new_df = pd.read_csv('Cosmetologists.csv', header=1)

# %%
new_df
# Out:
#         FIRSTNAME         LASTNAME                  ADDRESS1 ADDRESS2  \
# 0        Johnette          Bowling  4252 Mitchell Estate St.      NaN
# 1          Melody        Jefferson   2707-A Bluff View Drive      NaN
# 2         Ignacio  Quezada-Mendoza                       NaN      NaN
# 3      Aleksandra          Khudina        16e mansion woods       NaN
# 4         Natalie           Sharac           6 Kylene circle      NaN
# ...           ...              ...                       ...      ...
# 79618         NaN              NaN                       NaN      NaN
# 79619         NaN              NaN                       NaN      NaN
# 79620         NaN              NaN                       NaN      NaN
# 79621         NaN              NaN                       NaN      NaN
# 79622         NaN              NaN                       NaN      NaN
#
#               CITY State Code ZIPCODE LIC TYPE CODE  LICENSENUM DATEOFEXPIRY  \
# ...

# %%
new_df = new_df.rename(columns={'FIRSTNAME':'First Name', 'LASTNAME':'Last Name'})

# %%
new_df
# Out:
#        First Name        Last Name                  ADDRESS1 ADDRESS2  \
# 0        Johnette          Bowling  4252 Mitchell Estate St.      NaN
# 1          Melody        Jefferson   2707-A Bluff View Drive      NaN
# 2         Ignacio  Quezada-Mendoza                       NaN      NaN
# 3      Aleksandra          Khudina        16e mansion woods       NaN
# 4         Natalie           Sharac           6 Kylene circle      NaN
# ...           ...              ...                       ...      ...
# 79618         NaN              NaN                       NaN      NaN
# 79619         NaN              NaN                       NaN      NaN
# 79620         NaN              NaN                       NaN      NaN
# 79621         NaN              NaN                       NaN      NaN
# 79622         NaN              NaN                       NaN      NaN
#
#               CITY State Code ZIPCODE LIC TYPE CODE  LICENSENUM DATEOFEXPIRY  \
# ...

# %%
new_df = new_df.drop(columns='ADDRESS2')

# %%
new_df = new_df.dropna()

# %%
new_df
# Out:
#        First Name       Last Name                  ADDRESS1          CITY  \
# 0        Johnette         Bowling  4252 Mitchell Estate St.        Sophia
# 1          Melody       Jefferson   2707-A Bluff View Drive    Greenville
# 3      Aleksandra         Khudina        16e mansion woods         Agawam
# 4         Natalie          Sharac           6 Kylene circle   Southampton
# 5           Lakyn           Brozo    114 Belchertown Street  Three Rivers
# ...           ...             ...                       ...           ...
# 71899  Bernadette         Markins               P O Box 258       Wailuku
# 71900       Terri           Luong              PO Box 22366      Honolulu
# 71901    Shaniqua         Dickson         29652 18th Ave S.   Federal Way
# 71902      Krista         Vrolyks           610 NW 114th St     Vancouver
# 71903    Margaret  Gomez-Gonzalez           4723 N Smith St       Spokane
#
#       State Code ZIPCODE LIC TYPE CODE  LICENSENUM DATEOFEXPIRY  \
# ...

# %%
new_df = new_df.rename(columns={'ADDRESS1': 'Address', 'CITY':'City', 'State Code': 'State', 'ZIPCODE':'Zip', 'LIC TYPE CODE':'License Code', 'DATEOFEXPIRY':'Expiration Date'})

# %%
new_df = new_df.rename(columns={'LICENSENUM': 'License Number', 'LIC STATUS CODE': 'License Status Code'})

# %%
new_df
# Out:
#        First Name       Last Name                   Address          City  \
# 0        Johnette         Bowling  4252 Mitchell Estate St.        Sophia
# 1          Melody       Jefferson   2707-A Bluff View Drive    Greenville
# 3      Aleksandra         Khudina        16e mansion woods         Agawam
# 4         Natalie          Sharac           6 Kylene circle   Southampton
# 5           Lakyn           Brozo    114 Belchertown Street  Three Rivers
# ...           ...             ...                       ...           ...
# 71899  Bernadette         Markins               P O Box 258       Wailuku
# 71900       Terri           Luong              PO Box 22366      Honolulu
# 71901    Shaniqua         Dickson         29652 18th Ave S.   Federal Way
# 71902      Krista         Vrolyks           610 NW 114th St     Vancouver
# 71903    Margaret  Gomez-Gonzalez           4723 N Smith St       Spokane
#
#       State    Zip License Code  License Number Expiration Date  \
# ...

# %%
nc_df = new_df.loc[new_df['State'] == 'NC']

# %%
nc_df = nc_df.reset_index()

# %%
sc_df = new_df.loc[new_df['State'] == 'SC']

# %%
sc_df = sc_df.reset_index()

# %%
nc_df = nc_df.drop(columns = ['index'])

# %%
sc_df = sc_df.drop(columns = ['index'])

# %%
## Checking for Duplicates
nc_df.drop_duplicates()
# Out:
#       First Name    Last Name                   Address           City State  \
# 0       Johnette      Bowling  4252 Mitchell Estate St.         Sophia    NC
# 1         Melody    Jefferson   2707-A Bluff View Drive     Greenville    NC
# 2         Tomeka        Adams      600 Joshua pl nw #24       Concord     NC
# 3         Carrie       Garner        144 Enfield Street      Hartford     NC
# 4        Tabitha      Kistler           5250 Highway 73  Iron Station     NC
# ...          ...          ...                       ...            ...   ...
# 64936       Lori  Bird-Webber        318 hawthorne lane         murphy    NC
# 64937      Linda       Creech          1300 Tilson Road         MURPHY    NC
# 64938      Heidi      Lampman            30 Duke Street         MURPHY    NC
# 64939     Brenda      Ledford       35 Hardy Truett Rd.         Murphy    NC
# 64940       Anya       Beaver           267 Bryson Road         MURPHY    NC
#
# ...

# %%
sc_df.drop_duplicates()
# Out:
#      First Name   Last Name                Address                City State  \
# 0      Margaret     Berkley       973 platinum dr.           Fort mill    SC
# 1        Thamar      Vernet  160 Lodges Ln Apt 108              Clover    SC
# 2       Suzanne    Karkoska         608 22nd ave n  North myrtle beach    SC
# 3         Robyn       Pirog        116 Adelphia Rd               Loris    SC
# 4     Katherine      Miller      486 Gloria court            Florence     SC
# ...         ...         ...                    ...                 ...   ...
# 1968      Tonya      Walker      435 red oak drive               aiken    SC
# 1969   Jennifer   Underwood   126 Horry street se                Aiken    SC
# 1970    Claudia  Herrington           46 Birch Dr.           Beaufort     SC
# 1971    Tiffany     Burnett  53 Confederate Avenue           Bluffton     SC
# 1972  Elizabeth       Mayer  127 Lake Linden Drive            Bluffton    SC
#
# ...

# %%
nc_df.dtypes
# Out:
# First Name              object
# Last Name               object
# Address                 object
# City                    object
# State                   object
# Zip                     object
# License Code            object
# License Number         float64
# Expiration Date         object
# License Status Code     object
# dtype: object

# %%
from pandas import to_datetime
import datetime

# %%
nc_df['Expiration Date'] = pd.to_datetime(nc_df['Expiration Date'])
nc_df
# Out:
#       First Name    Last Name                   Address           City State  \
# 0       Johnette      Bowling  4252 Mitchell Estate St.         Sophia    NC
# 1         Melody    Jefferson   2707-A Bluff View Drive     Greenville    NC
# 2         Tomeka        Adams      600 Joshua pl nw #24       Concord     NC
# 3         Carrie       Garner        144 Enfield Street      Hartford     NC
# 4        Tabitha      Kistler           5250 Highway 73  Iron Station     NC
# ...          ...          ...                       ...            ...   ...
# 64936       Lori  Bird-Webber        318 hawthorne lane         murphy    NC
# 64937      Linda       Creech          1300 Tilson Road         MURPHY    NC
# 64938      Heidi      Lampman            30 Duke Street         MURPHY    NC
# 64939     Brenda      Ledford       35 Hardy Truett Rd.         Murphy    NC
# 64940       Anya       Beaver           267 Bryson Road         MURPHY    NC
#
# ...

# %%
nc_df_2021 = nc_df[nc_df['Expiration Date'].dt.year == 2021]
nc_df_2022 = nc_df[nc_df['Expiration Date'].dt.year == 2022]
nc_df_2023 = nc_df[nc_df['Expiration Date'].dt.year == 2023]
nc_df_2021 = nc_df_2021.reset_index()
nc_df_2022 = nc_df_2022.reset_index()
nc_df_2023 = nc_df_2023.reset_index()

# %%
new_nc_df = nc_df_2021.append(nc_df_2022)
new_nc_df = new_nc_df.append(nc_df_2023)
new_nc_df = new_nc_df.reset_index()
new_nc_df = new_nc_df.drop(columns = ['index', 'level_0'])
new_nc_df
# Out:
# /var/folders/jm/4cwpb48s6xv_vgw8y_7bdnn80000gn/T/ipykernel_51899/950667069.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_nc_df = nc_df_2021.append(nc_df_2022)
# /var/folders/jm/4cwpb48s6xv_vgw8y_7bdnn80000gn/T/ipykernel_51899/950667069.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_nc_df = new_nc_df.append(nc_df_2023)
#          First Name Last Name                   Address         City State  \
# 0      Huong Nguyen      Dinh           9505 SEAMILL RD    CHARLOTTE    NC
# 1             Corey  Williams       120 Applecross Dr.   Franklinton    NC
# 2               Kim    Hawley    525 Christmas tree rd          Dunn    NC
# 3             Shara     Owens          PSC 103 Box 2527      APO, AE    NC
# 4              Emma   Patrick  2039 E Hudson Blvd Apt H     Gastonia    NC
# ...

# %%
sc_df['Expiration Date'] = pd.to_datetime(sc_df['Expiration Date'])
sc_df
# Out:
#      First Name   Last Name                Address                City State  \
# 0      Margaret     Berkley       973 platinum dr.           Fort mill    SC
# 1        Thamar      Vernet  160 Lodges Ln Apt 108              Clover    SC
# 2       Suzanne    Karkoska         608 22nd ave n  North myrtle beach    SC
# 3         Robyn       Pirog        116 Adelphia Rd               Loris    SC
# 4     Katherine      Miller      486 Gloria court            Florence     SC
# ...         ...         ...                    ...                 ...   ...
# 1968      Tonya      Walker      435 red oak drive               aiken    SC
# 1969   Jennifer   Underwood   126 Horry street se                Aiken    SC
# 1970    Claudia  Herrington           46 Birch Dr.           Beaufort     SC
# 1971    Tiffany     Burnett  53 Confederate Avenue           Bluffton     SC
# 1972  Elizabeth       Mayer  127 Lake Linden Drive            Bluffton    SC
#
# ...

# %%
sc_df_2021 = sc_df[sc_df['Expiration Date'].dt.year == 2021]
sc_df_2022 = sc_df[sc_df['Expiration Date'].dt.year == 2022]
sc_df_2023 = sc_df[sc_df['Expiration Date'].dt.year == 2023]
sc_df_2021 = sc_df_2021.reset_index()
sc_df_2022 = sc_df_2022.reset_index()
sc_df_2023 = sc_df_2023.reset_index()

# %%
new_sc_df = sc_df_2021.append(sc_df_2022)
new_sc_df = new_sc_df.append(sc_df_2023)
new_sc_df = new_sc_df.reset_index()
new_sc_df = new_sc_df.drop(columns = ['index', 'level_0'])
new_sc_df
# Out:
# /var/folders/jm/4cwpb48s6xv_vgw8y_7bdnn80000gn/T/ipykernel_51899/573678160.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_sc_df = sc_df_2021.append(sc_df_2022)
# /var/folders/jm/4cwpb48s6xv_vgw8y_7bdnn80000gn/T/ipykernel_51899/573678160.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_sc_df = new_sc_df.append(sc_df_2023)
#      First Name      Last Name                     Address  \
# 0       Jessica        Crafton          5105 mill creek rd
# 1       Juleigh       Gallaway               115 Griggs rd
# 2        Rachel  Blankenbecler         2040 Zelkova Drive
# 3         Megan        Ferrell      1208 Hammond carnes Rd
# 4        Sophia         Gibson   3499 North Rocky River Rd
# ...         ...            ...                         ...
# ...

# %%
del nc_df
del sc_df

# %%
nc_df = new_nc_df
sc_df = new_sc_df

# %%
nc_df['Full Address'] = nc_df['Address']  + ' ' + nc_df['City'] + ' ' + nc_df['State']
sc_df['Full Address'] = sc_df['Address']  + ' ' + sc_df['City'] + ' ' + sc_df['State']

# %%
nc_df
# Out:
#          First Name Last Name                   Address         City State  \
# 0      Huong Nguyen      Dinh           9505 SEAMILL RD    CHARLOTTE    NC
# 1             Corey  Williams       120 Applecross Dr.   Franklinton    NC
# 2               Kim    Hawley    525 Christmas tree rd          Dunn    NC
# 3             Shara     Owens          PSC 103 Box 2527      APO, AE    NC
# 4              Emma   Patrick  2039 E Hudson Blvd Apt H     Gastonia    NC
# ...             ...       ...                       ...          ...   ...
# 52926         Suong      Veng          222 ROANOKE ROAD     FLETCHER    NC
# 52927        Silvia     Gallo       5305 Bakers Mill RD       Durham    NC
# 52928         selam    yosief  7701 creekridge rd #1003   charlotte     NC
# 52929         Emily    Barnes          676 Harris St NW      Concord    NC
# 52930        Jackie    Kramek      20080 Hosmer mine ct   Foresthill    NC
#
#           Zip License Code  License Number Expiration Date  \
# ...

# %%
from googlemaps import Client as GoogleMaps
gmaps = GoogleMaps('AIzaSyAgPOy0qY-0IRWKJhAzbw9XaKI_YhkecD0')

# %%
sc_df['Latitude'] = ""
sc_df['Longitude'] = ""
sc_lat = []
sc_lng = []
sc_addresses = sc_df['Full Address'].tolist()

# %%
# sc_addresses

# %%
import asyncio
import time

# %%
import nest_asyncio
nest_asyncio.apply()
import aiohttp
import json

# %% [raw]
# async def myCoroutine():
#     for x in range(len(sc_df)):
#         geocode_result = gmaps.geocode(sc_df['Full Address'][x])
# #         await asyncio.sleep(1)
#         sc_df['Latitude'][x] = geocode_result[0]['geometry']['location'] ['lat']
# #         await asyncio.sleep(1)
#         sc_df['Longitude'][x] = geocode_result[0]['geometry']['location']['lng']
# #         await asyncio.sleep(1)

# %% [raw]
# if __name__ == '__main__':
#     loop = asyncio.get_event_loop()
# #     tasks = (myCoroutine(x) for x in enumerate(sc_addresses))
#     loop.run_until_complete(myCoroutine())
# asyncio.run(myCoroutine())

# %% [raw]
# sc_df

# %% [raw]
# nc_df['Latitude'] = ""
# nc_df['Longitude'] = ""
# nc_lat = []
# nc_lng = []
# nc_addresses = nc_df['Full Address'].tolist()

# %% [raw]
# async def myCoroutine():
#     for x in range(len(nc_df)):
#         geocode_result = gmaps.geocode(nc_df['Full Address'][x])
# #         await asyncio.sleep(1)
#         nc_df['Latitude'][x] = geocode_result[0]['geometry']['location'] ['lat']
# #         await asyncio.sleep(1)
#         nc_df['Longitude'][x] = geocode_result[0]['geometry']['location']['lng']
# #         await asyncio.sleep(1)

# %% [raw]
# if __name__ == '__main__':
#     loop = asyncio.get_event_loop()
# #     tasks = (myCoroutine(x) for x in enumerate(nc_addresses))
#     loop.run_until_complete(myCoroutine())
# asyncio.run(myCoroutine())

# %% [raw]
# nc_df

# %% [raw]
# sc_df.to_csv('south_carolina.csv', index=False, header=True)

# %% [raw]
# for x in range(len(nc_df)):
#     try:
#         time.sleep(1) #to add delay in case of large DFs
#         geocode_result = gmaps.geocode(nc_df['Full Address'][x])
#         nc_df['Latitude'][x] = geocode_result[0]['geometry']['location'] ['lat']
#         nc_df['Longitude'][x] = geocode_result[0]['geometry']['location']['lng']
#     except:
#         print('Nope')

# %% [raw]
# import geopy
# from geopy import GoogleV3
# geolocator = GoogleV3(api_key='AIzaSyAgPOy0qY-0IRWKJhAzbw9XaKI_YhkecD0')

# %% [raw]
# nc_df["loc"] = nc_df["Full Address"].apply(geolocator.geocode)

# %% [raw]
# nc_df["point"]= nc_df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)

# %% [raw]
# nc_df[['Latitude', 'Longitude', 'Altitude']] = pd.DataFrame(nc_df['point'].to_list(), index=nc_df.index)

# %% [raw]
# nc_df = nc_df.drop(columns=['loc', 'point', 'Altitude'])

# %% [raw]
# nc_df

# %% [raw]
# locations = sc_df[["Latitude", "Longitude"]].astype(float)
# locations_2 = nc_df[["Latitude", "Longitude"]].astype(float)

# %% [raw]
# sc_df["loc"] = sc_df["Full Address"].apply(geolocator.geocode)
# sc_df["point"]= sc_df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)
# sc_df[['Latitude', 'Longitude', 'Altitude']] = pd.DataFrame(sc_df['point'].to_list(), index=sc_df.index)

# %% [raw]
# sc_df = sc_df.drop(columns=['loc', 'point', 'Altitude'])

# %% [raw]
# sc_df

# %%
nc_df = pd.read_csv('north_carolina.csv', names=['First Name', 'Last Name', 'Address', 'City', 'State', 'Zip', 'License Code', 'License Number', 'Expiration Date', 'License Status Code', 'Full Address', 'Latitude', 'Longitude'], skiprows=1)
sc_df = pd.read_csv('south_carolina.csv', names=['First Name', 'Last Name', 'Address', 'City', 'State', 'Zip', 'License Code', 'License Number', 'Expiration Date', 'License Status Code', 'Full Address', 'Latitude', 'Longitude'], skiprows=1)

# %%
sc_df.to_csv('south_carolina.csv', index=False, header=True)

# %%
nc_df.to_csv('north_carolina.csv', index=False, header=True)

# %%
nc_df = nc_df.iloc[1: , :]
nc_df
# Out:
#          First Name  Last Name                   Address        City  State  \
# 1        First Name  Last Name                   Address        City  State
# 2        First Name  Last Name                   Address        City  State
# 3        First Name  Last Name                   Address        City  State
# 4        First Name  Last Name                   Address        City  State
# 5      Huong Nguyen       Dinh           9505 Seamill Rd   Charlotte     NC
# ...             ...        ...                       ...         ...    ...
# 52931         Suong       Veng          222 Roanoke Road    Fletcher     NC
# 52932        Silvia      Gallo       5305 Bakers Mill Rd      Durham     NC
# 52933         selam     yosief  7701 Creekridge Rd #1003  Charlotte      NC
# 52934         Emily     Barnes          676 Harris St Nw     Concord     NC
# 52935        Jackie     Kramek      20080 Hosmer Mine Ct  Foresthill     NC
#
# ...

# %%
sc_df
# Out:
#       First Name     Last Name                     Address  \
# 0     First Name     Last Name                     Address
# 1     First Name     Last Name                     Address
# 2     First Name     Last Name                     Address
# 3     First Name     Last Name                     Address
# 4     First Name     Last Name                     Address
# ...          ...           ...                         ...
# 1357       Janet       Krewson           14 Sawtooth Court
# 1358      Linda   Ange Ambrose  231 Ridgeland Lakes Drive
# 1359      Tyisha       Sumpter             163 Trask Pkwy
# 1360      Melody        Worley        3 Lindsey Hill Trail
# 1361    Madelynn       Poeggel         9825 English Elm St
#
#                     City  State    Zip  License Code  License Number  \
# 0                   City  State    Zip  License Code  License Number
# 1                   City  State    Zip  License Code  License Number
# ...

# %%
# locations = sc_df[["Latitude", "Longitude"]].astype(float)
# locations_2 = nc_df[["Latitude", "Longitude"]].astype(float)

# %%
import gmaps
gmaps.configure(api_key='AIzaSyAgPOy0qY-0IRWKJhAzbw9XaKI_YhkecD0')

# %% [raw]
# fig = gmaps.figure()
#
# fig.add_layer(gmaps.heatmap_layer(locations))
#
# fig

# %%
nc_df = nc_df.dropna()

# %%
nc_df
# Out:
#          First Name  Last Name                   Address        City  State  \
# 1        First Name  Last Name                   Address        City  State
# 2        First Name  Last Name                   Address        City  State
# 3        First Name  Last Name                   Address        City  State
# 4        First Name  Last Name                   Address        City  State
# 5      Huong Nguyen       Dinh           9505 Seamill Rd   Charlotte     NC
# ...             ...        ...                       ...         ...    ...
# 52931         Suong       Veng          222 Roanoke Road    Fletcher     NC
# 52932        Silvia      Gallo       5305 Bakers Mill Rd      Durham     NC
# 52933         selam     yosief  7701 Creekridge Rd #1003  Charlotte      NC
# 52934         Emily     Barnes          676 Harris St Nw     Concord     NC
# 52935        Jackie     Kramek      20080 Hosmer Mine Ct  Foresthill     NC
#
# ...

# %%
nc_df['City'] = nc_df['City'].str.title()
sc_df['City'] = sc_df['City'].str.title()
nc_df['Address'] = nc_df['Address'].str.title()
sc_df['Address'] = sc_df['Address'].str.title()
nc_df['Full Address'] = nc_df['Full Address'].str.title()
sc_df['Full Address'] = sc_df['Full Address'].str.title()
# Out:
# /var/folders/jm/4cwpb48s6xv_vgw8y_7bdnn80000gn/T/ipykernel_51899/1022909501.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nc_df['City'] = nc_df['City'].str.title()
# /var/folders/jm/4cwpb48s6xv_vgw8y_7bdnn80000gn/T/ipykernel_51899/1022909501.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nc_df['Address'] = nc_df['Address'].str.title()
# /var/folders/jm/4cwpb48s6xv_vgw8y_7bdnn80000gn/T/ipykernel_51899/1022909501.py:5: SettingWithCopyWarning:
# ...

# %%
nc_df = pd.DataFrame(None)

# %%
nc_df = pd.read_csv('north_carolina.csv', names=['First Name', 'Last Name', 'Address', 'City', 'State', 'Zip', 'License Code', 'License Number', 'Expiration Date', 'License Status Code', 'Full Address', 'Latitude', 'Longitude'])
sc_df = pd.read_csv('south_carolina.csv', names=['First Name', 'Last Name', 'Address', 'City', 'State', 'Zip', 'License Code', 'License Number', 'Expiration Date', 'License Status Code', 'Full Address', 'Latitude', 'Longitude'])

# %%
nc_df['City'] = nc_df['City'].str.title()
sc_df['City'] = sc_df['City'].str.title()
nc_df['Address'] = nc_df['Address'].str.title()
sc_df['Address'] = sc_df['Address'].str.title()
nc_df['Full Address'] = nc_df['Full Address'].str.title()
sc_df['Full Address'] = sc_df['Full Address'].str.title()

# %%
nc_df.to_csv('north_carolina.csv', index=False, header=True)
sc_df.to_csv('south_carolina.csv', index=False, header=True)

# %%
new_df = pd.read_csv('south_carolina.csv')
new_df
# Out:
#       First Name     Last Name                     Address  \
# 0     First Name     Last Name                     Address
# 1     First Name     Last Name                     Address
# 2     First Name     Last Name                     Address
# 3     First Name     Last Name                     Address
# 4     First Name     Last Name                     Address
# ...          ...           ...                         ...
# 1359       Janet       Krewson           14 Sawtooth Court
# 1360      Linda   Ange Ambrose  231 Ridgeland Lakes Drive
# 1361      Tyisha       Sumpter             163 Trask Pkwy
# 1362      Melody        Worley        3 Lindsey Hill Trail
# 1363    Madelynn       Poeggel         9825 English Elm St
#
#                     City  State    Zip  License Code  License Number  \
# 0                   City  State    Zip  License Code  License Number
# 1                   City  State    Zip  License Code  License Number
# ...

# %%
charlotte_df = nc_df.loc[nc_df['City'] == 'Charlotte']
charlotte_df = charlotte_df.reset_index()
charlotte_df = charlotte_df.drop(columns=['index'])
charlotte_df.to_csv('charlotte.csv', index=False, header=True)

# %%
nc_df['City'].value_counts().head(50)
# Out:
# Charlotte         4920
# Raleigh           2732
# Greensboro        1765
# Durham            1387
# Fayetteville      1370
# Wilmington        1238
# Winston Salem      978
# Concord            719
# Jacksonville       618
# Asheville          577
# Cary               550
# High Point         544
# Gastonia           524
# Mooresville        500
# Monroe             477
# Greenville         467
# Hickory            432
# Burlington         422
# Statesville        404
# Salisbury          396
# Clayton            386
# Sanford            364
# Lexington          354
# Matthews           342
# Goldsboro          340
# Wake Forest        335
# Kannapolis         328
# Hendersonville     326
# Apex               326
# Kernersville       311
# New Bern           306
# Garner             306
# Rocky Mount        301
# Asheboro           282
# Wilson             270
# Shelby             267
# Waxhaw             264
# Huntersville       259
# Lincolnton         253
# Fuquay Varina      239
# ...

# %%
charlotte_df
# Out:
#         First Name Last Name                         Address       City State  \
# 0     Huong Nguyen      Dinh                 9505 Seamill Rd  Charlotte    NC
# 1           Justin  Flournoy           2229 Village Lake Dr.  Charlotte    NC
# 2         Joanne E    Reeves                 2000 Paladin Ct  Charlotte    NC
# 3           Lamont      Cary                2000 South Blvd.  Charlotte    NC
# 4              Bao      Yang        2915 Phillips Fairway Dr  Charlotte    NC
# ...            ...       ...                             ...        ...   ...
# 4915       Sharell     Daley  12820 Winter Hazel Rd. Apt 208  Charlotte    NC
# 4916        Kristy  Harrison                 P. O. Box 16861  Charlotte    NC
# 4917        LaTrea     Ricks          316 North Rhett Street  Charlotte    NC
# 4918        Yfaina      Diaz    7800 Royal Point Dr Apt 104   Charlotte    NC
# 4919        Kiarra     Grant            6908 Dixie River Rd.  Charlotte    NC
#
# ...

# %%
url = "https://data.searchbug.com/api/search.aspx?CO_CODE='12617834'&PASS='Ruger2012!?'&TYPE='api_phone'&ADDRESS='4252 Mitchell Estate St'&CITY='Sophia'&STATE='NC'&ZIP='27350'&FORMAT='JSON'"

# %%
import requests
phone_num = []
charlotte_df['Last Name'] = charlotte_df['Last Name'].str.upper()
charlotte_df['Address'] = charlotte_df['Address'].str.upper()
charlotte_df['Zip'] = charlotte_df['Zip'][:5]
charlotte_df['Zip'] = charlotte_df['Zip'].astype('str')
charlotte_df['Address'] = charlotte_df['Address'].str.replace(r'[^\w\s]+', '')
charlotte_df["Address"]= charlotte_df['Address'].str.replace(' STREET', ' ST')
charlotte_df["Address"]= charlotte_df['Address'].str.replace(' BOULEVARD', ' BLVD')
charlotte_df["Address"]= charlotte_df['Address'].str.replace(' COURT', " CT")
charlotte_df["Address"]= charlotte_df['Address'].str.replace(' ROAD', ' RD')
charlotte_df["Address"]= charlotte_df['Address'].str.replace(' LANE', ' LN')
charlotte_df["Address"]= charlotte_df['Address'].str.replace(' PLACE', ' PL')
# Out:
# /var/folders/jm/4cwpb48s6xv_vgw8y_7bdnn80000gn/T/ipykernel_51899/556617231.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   charlotte_df['Address'] = charlotte_df['Address'].str.replace(r'[^\w\s]+', '')

# %%
charlotte_df = charlotte_df.dropna(subset=['Address'])
charlotte_df
# Out:
#         First Name Last Name                        Address       City State  \
# 0     Huong Nguyen      DINH                9505 SEAMILL RD  Charlotte    NC
# 1           Justin  FLOURNOY           2229 VILLAGE LAKE DR  Charlotte    NC
# 2         Joanne E    REEVES                2000 PALADIN CT  Charlotte    NC
# 3           Lamont      CARY                2000 SOUTH BLVD  Charlotte    NC
# 4              Bao      YANG       2915 PHILLIPS FAIRWAY DR  Charlotte    NC
# ...            ...       ...                            ...        ...   ...
# 4915       Sharell     DALEY  12820 WINTER HAZEL RD APT 208  Charlotte    NC
# 4916        Kristy  HARRISON                  P O BOX 16861  Charlotte    NC
# 4917        LaTrea     RICKS             316 NORTH RHETT ST  Charlotte    NC
# 4918        Yfaina      DIAZ   7800 ROYAL POINT DR APT 104   Charlotte    NC
# 4919        Kiarra     GRANT            6908 DIXIE RIVER RD  Charlotte    NC
#
# ...

# %%
phone_num = []
for i in range(len(charlotte_df)):
    query_url = f'https://data.searchbug.com/api/search.aspx?CO_CODE=12617834&PASS=Ruger2012!?&TYPE=api_phone&ADDRESS={charlotte_df.Address[i]}&CITY=Charlotte&STATE=NC&FORMAT=JSON'
    response = requests.get(query_url)
    response2 = response.json()
    for x in range(len(response2) - 1):
        if response2['STATUS'] == 'SUCCESS' and response2['DATA']['RECORD'][x]['LNAME'] == charlotte_df['Last Name'][i]:
            phone_num.append(response2['DATA']['RECORD'][x]['PHONE'])
            break
        else:
            if response2['STATUS'] == 'SUCCESS' and response2['DATA']['RECORD'][(x + 1)]['LNAME'] == charlotte_df['Last Name'][i]:
                phone_num.append(response2['DATA']['RECORD'][(x + 1)]['PHONE'])
                break
            else:
                phone_num.append('NaN')
                break
phone_num = []

# %%
phone_num
# Out:
# []

# %%
phone_num = []
query_url = "https://data.searchbug.com/api/search.aspx?CO_CODE='12617834'&PASS='Ruger2012!?'&TYPE='api_phone'&ADDRESS='charlotte_df.Address[0]'&CITY='Charlotte'&STATE='NC'&FORMAT='JSON'"
response = requests.get(query_url)
response2 = response.json()
for x in range(2):
    if response2['STATUS'] == 'SUCCESS' and response2['DATA']['RECORD'][x]['LNAME'] == charlotte_df['Last Name'][0]:
        phone_num.append(response2['DATA']['RECORD'][x]['PHONE'])
        break
    elif response2['STATUS'] == 'SUCCESS' and response2['DATA']['RECORD'][(x + 1)]['LNAME'] == charlotte_df['Last Name'][0]:
        phone_num.append(response2['DATA']['RECORD'][(x + 1)]['PHONE'])
        break
    else:
        phone_num.append('NaN')
        break
phone_num
# Out:
# ['NaN']

# %%
print(response2)
# Out:
# {'STATUS': 'NORESULTS', 'DATA': None, 'ERROR': None}

# %%
# &ZIP='charlotte_df['Zip'][i]'
charlotte_df['Address'][0]
# Out:
# '9505 SEAMILL RD'

# %%
query_url = f'https://data.searchbug.com/api/search.aspx?CO_CODE=12617834&PASS=Ruger2012!?&TYPE=api_phone&ADDRESS=316 NORTH RHETT ST&CITY=Charlotte&STATE=NC&FORMAT=JSON'
response = requests.get(query_url)
response2 = response.json()
response2
# Out:
# {'STATUS': 'NORESULTS', 'DATA': None, 'ERROR': None}

# %% [raw]
# for x in range(len(response2) - 1):
#     if response2['STATUS'] == 'SUCCESS' and response2['DATA']['RECORD'][0]['LNAME'] == charlotte_df['Last Name'][1]:
#         print('Correct')

# %% [raw]
# if response2['STATUS'] == 'SUCCESS':
#     print('yay')

# %% [raw]
# huntersville_df = nc_df.loc[nc_df['City'] == 'Huntersville']
# huntersville_df = huntersville_df.reset_index()
# huntersville_df = huntersville_df.drop(columns=['index'])
# huntersville_df.to_csv('huntersville.csv', index=False, header=True)

# %% [raw]
# concord_df = nc_df.loc[nc_df['City'] == 'Concord']
# concord_df = concord_df.reset_index()
# concord_df = concord_df.drop(columns=['index'])
# concord_df.to_csv('concord.csv', index=False, header=True)

# %% [raw]
# gastonia_df = nc_df.loc[nc_df['City'] == 'Gastonia']
# gastonia_df = gastonia_df.reset_index()
# gastonia_df = gastonia_df.drop(columns=['index'])
# gastonia_df.to_csv('gastonia.csv', index=False, header=True)

# %% [raw]
# matthews_df = nc_df.loc[nc_df['City'] == 'Matthews']
# matthews_df = matthews_df.reset_index()
# matthews_df = matthews_df.drop(columns=['index'])
# matthews_df.to_csv('matthews.csv', index=False, header=True)

# %% [raw]
# kannapolis_df = nc_df.loc[nc_df['City'] == 'Kannapolis']
# kannapolis_df = kannapolis_df.reset_index()
# kannapolis_df = kannapolis_df.drop(columns=['index'])
# kannapolis_df.to_csv('kannapolis.csv', index=False, header=True)

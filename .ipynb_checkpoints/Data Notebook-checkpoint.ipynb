# %%
import pandas as pd

# %%
new_df = pd.read_csv('Cosmetologists.csv', header=1)

# %%
new_df
# Out:
#         FIRSTNAME         LASTNAME                  ADDRESS1 ADDRESS2  \
# 0        Johnette          Bowling  4252 Mitchell Estate St.      NaN
# 1          Melody        Jefferson   2707-A Bluff View Drive      NaN
# 2         Ignacio  Quezada-Mendoza                       NaN      NaN
# 3      Aleksandra          Khudina        16e mansion woods       NaN
# 4         Natalie           Sharac           6 Kylene circle      NaN
# ...           ...              ...                       ...      ...
# 79618         NaN              NaN                       NaN      NaN
# 79619         NaN              NaN                       NaN      NaN
# 79620         NaN              NaN                       NaN      NaN
# 79621         NaN              NaN                       NaN      NaN
# 79622         NaN              NaN                       NaN      NaN
#
#               CITY State Code ZIPCODE LIC TYPE CODE  LICENSENUM DATEOFEXPIRY  \
# ...

# %%
new_df = new_df.rename(columns={'FIRSTNAME':'First Name', 'LASTNAME':'Last Name'})

# %%
new_df
# Out:
#        First Name        Last Name                  ADDRESS1 ADDRESS2  \
# 0        Johnette          Bowling  4252 Mitchell Estate St.      NaN
# 1          Melody        Jefferson   2707-A Bluff View Drive      NaN
# 2         Ignacio  Quezada-Mendoza                       NaN      NaN
# 3      Aleksandra          Khudina        16e mansion woods       NaN
# 4         Natalie           Sharac           6 Kylene circle      NaN
# ...           ...              ...                       ...      ...
# 79618         NaN              NaN                       NaN      NaN
# 79619         NaN              NaN                       NaN      NaN
# 79620         NaN              NaN                       NaN      NaN
# 79621         NaN              NaN                       NaN      NaN
# 79622         NaN              NaN                       NaN      NaN
#
#               CITY State Code ZIPCODE LIC TYPE CODE  LICENSENUM DATEOFEXPIRY  \
# ...

# %%
new_df = new_df.drop(columns='ADDRESS2')

# %%
new_df = new_df.dropna()

# %%
new_df
# Out:
#        First Name       Last Name                  ADDRESS1          CITY  \
# 0        Johnette         Bowling  4252 Mitchell Estate St.        Sophia
# 1          Melody       Jefferson   2707-A Bluff View Drive    Greenville
# 3      Aleksandra         Khudina        16e mansion woods         Agawam
# 4         Natalie          Sharac           6 Kylene circle   Southampton
# 5           Lakyn           Brozo    114 Belchertown Street  Three Rivers
# ...           ...             ...                       ...           ...
# 71899  Bernadette         Markins               P O Box 258       Wailuku
# 71900       Terri           Luong              PO Box 22366      Honolulu
# 71901    Shaniqua         Dickson         29652 18th Ave S.   Federal Way
# 71902      Krista         Vrolyks           610 NW 114th St     Vancouver
# 71903    Margaret  Gomez-Gonzalez           4723 N Smith St       Spokane
#
#       State Code ZIPCODE LIC TYPE CODE  LICENSENUM DATEOFEXPIRY  \
# ...

# %%
new_df = new_df.rename(columns={'ADDRESS1': 'Address', 'CITY':'City', 'State Code': 'State', 'ZIPCODE':'Zip', 'LIC TYPE CODE':'License Code', 'DATEOFEXPIRY':'Expiration Date'})

# %%
new_df = new_df.rename(columns={'LICENSENUM': 'License Number', 'LIC STATUS CODE': 'License Status Code'})

# %%
new_df
# Out:
#        First Name       Last Name                   Address          City  \
# 0        Johnette         Bowling  4252 Mitchell Estate St.        Sophia
# 1          Melody       Jefferson   2707-A Bluff View Drive    Greenville
# 3      Aleksandra         Khudina        16e mansion woods         Agawam
# 4         Natalie          Sharac           6 Kylene circle   Southampton
# 5           Lakyn           Brozo    114 Belchertown Street  Three Rivers
# ...           ...             ...                       ...           ...
# 71899  Bernadette         Markins               P O Box 258       Wailuku
# 71900       Terri           Luong              PO Box 22366      Honolulu
# 71901    Shaniqua         Dickson         29652 18th Ave S.   Federal Way
# 71902      Krista         Vrolyks           610 NW 114th St     Vancouver
# 71903    Margaret  Gomez-Gonzalez           4723 N Smith St       Spokane
#
#       State    Zip License Code  License Number Expiration Date  \
# ...

# %%
nc_df = new_df.loc[new_df['State'] == 'NC']

# %%
nc_df = nc_df.reset_index()

# %%
sc_df = new_df.loc[new_df['State'] == 'SC']

# %%
sc_df = sc_df.reset_index()

# %%
nc_df = nc_df.drop(columns = ['index'])

# %%
sc_df = sc_df.drop(columns = ['index'])

# %%
## Checking for Duplicates
nc_df.drop_duplicates()
# Out:
#       First Name    Last Name                   Address           City State  \
# 0       Johnette      Bowling  4252 Mitchell Estate St.         Sophia    NC
# 1         Melody    Jefferson   2707-A Bluff View Drive     Greenville    NC
# 2         Tomeka        Adams      600 Joshua pl nw #24       Concord     NC
# 3         Carrie       Garner        144 Enfield Street      Hartford     NC
# 4        Tabitha      Kistler           5250 Highway 73  Iron Station     NC
# ...          ...          ...                       ...            ...   ...
# 64936       Lori  Bird-Webber        318 hawthorne lane         murphy    NC
# 64937      Linda       Creech          1300 Tilson Road         MURPHY    NC
# 64938      Heidi      Lampman            30 Duke Street         MURPHY    NC
# 64939     Brenda      Ledford       35 Hardy Truett Rd.         Murphy    NC
# 64940       Anya       Beaver           267 Bryson Road         MURPHY    NC
#
# ...

# %%
sc_df.drop_duplicates()
# Out:
#      First Name   Last Name                Address                City State  \
# 0      Margaret     Berkley       973 platinum dr.           Fort mill    SC
# 1        Thamar      Vernet  160 Lodges Ln Apt 108              Clover    SC
# 2       Suzanne    Karkoska         608 22nd ave n  North myrtle beach    SC
# 3         Robyn       Pirog        116 Adelphia Rd               Loris    SC
# 4     Katherine      Miller      486 Gloria court            Florence     SC
# ...         ...         ...                    ...                 ...   ...
# 1968      Tonya      Walker      435 red oak drive               aiken    SC
# 1969   Jennifer   Underwood   126 Horry street se                Aiken    SC
# 1970    Claudia  Herrington           46 Birch Dr.           Beaufort     SC
# 1971    Tiffany     Burnett  53 Confederate Avenue           Bluffton     SC
# 1972  Elizabeth       Mayer  127 Lake Linden Drive            Bluffton    SC
#
# ...

# %%
nc_df.dtypes
# Out:
# First Name              object
# Last Name               object
# Address                 object
# City                    object
# State                   object
# Zip                     object
# License Code            object
# License Number         float64
# Expiration Date         object
# License Status Code     object
# dtype: object

# %%
from pandas import to_datetime
import datetime

# %%
nc_df['Expiration Date'] = pd.to_datetime(nc_df['Expiration Date'])
nc_df
# Out:
#       First Name    Last Name                   Address           City State  \
# 0       Johnette      Bowling  4252 Mitchell Estate St.         Sophia    NC
# 1         Melody    Jefferson   2707-A Bluff View Drive     Greenville    NC
# 2         Tomeka        Adams      600 Joshua pl nw #24       Concord     NC
# 3         Carrie       Garner        144 Enfield Street      Hartford     NC
# 4        Tabitha      Kistler           5250 Highway 73  Iron Station     NC
# ...          ...          ...                       ...            ...   ...
# 64936       Lori  Bird-Webber        318 hawthorne lane         murphy    NC
# 64937      Linda       Creech          1300 Tilson Road         MURPHY    NC
# 64938      Heidi      Lampman            30 Duke Street         MURPHY    NC
# 64939     Brenda      Ledford       35 Hardy Truett Rd.         Murphy    NC
# 64940       Anya       Beaver           267 Bryson Road         MURPHY    NC
#
# ...

# %%
nc_df_2021 = nc_df[nc_df['Expiration Date'].dt.year == 2021]
nc_df_2022 = nc_df[nc_df['Expiration Date'].dt.year == 2022]
nc_df_2023 = nc_df[nc_df['Expiration Date'].dt.year == 2023]
nc_df_2021 = nc_df_2021.reset_index()
nc_df_2022 = nc_df_2022.reset_index()
nc_df_2023 = nc_df_2023.reset_index()

# %%
new_nc_df = nc_df_2021.append(nc_df_2022)
new_nc_df = new_nc_df.append(nc_df_2023)
new_nc_df = new_nc_df.reset_index()
new_nc_df = new_nc_df.drop(columns = ['index', 'level_0'])
new_nc_df
# Out:
#          First Name Last Name                   Address         City State  \
# 0      Huong Nguyen      Dinh           9505 SEAMILL RD    CHARLOTTE    NC
# 1             Corey  Williams       120 Applecross Dr.   Franklinton    NC
# 2               Kim    Hawley    525 Christmas tree rd          Dunn    NC
# 3             Shara     Owens          PSC 103 Box 2527      APO, AE    NC
# 4              Emma   Patrick  2039 E Hudson Blvd Apt H     Gastonia    NC
# ...             ...       ...                       ...          ...   ...
# 52926         Suong      Veng          222 ROANOKE ROAD     FLETCHER    NC
# 52927        Silvia     Gallo       5305 Bakers Mill RD       Durham    NC
# 52928         selam    yosief  7701 creekridge rd #1003   charlotte     NC
# 52929         Emily    Barnes          676 Harris St NW      Concord    NC
# 52930        Jackie    Kramek      20080 Hosmer mine ct   Foresthill    NC
#
# ...

# %%
sc_df['Expiration Date'] = pd.to_datetime(sc_df['Expiration Date'])
sc_df
# Out:
#      First Name   Last Name                Address                City State  \
# 0      Margaret     Berkley       973 platinum dr.           Fort mill    SC
# 1        Thamar      Vernet  160 Lodges Ln Apt 108              Clover    SC
# 2       Suzanne    Karkoska         608 22nd ave n  North myrtle beach    SC
# 3         Robyn       Pirog        116 Adelphia Rd               Loris    SC
# 4     Katherine      Miller      486 Gloria court            Florence     SC
# ...         ...         ...                    ...                 ...   ...
# 1968      Tonya      Walker      435 red oak drive               aiken    SC
# 1969   Jennifer   Underwood   126 Horry street se                Aiken    SC
# 1970    Claudia  Herrington           46 Birch Dr.           Beaufort     SC
# 1971    Tiffany     Burnett  53 Confederate Avenue           Bluffton     SC
# 1972  Elizabeth       Mayer  127 Lake Linden Drive            Bluffton    SC
#
# ...

# %%
sc_df_2021 = sc_df[sc_df['Expiration Date'].dt.year == 2021]
sc_df_2022 = sc_df[sc_df['Expiration Date'].dt.year == 2022]
sc_df_2023 = sc_df[sc_df['Expiration Date'].dt.year == 2023]
sc_df_2021 = sc_df_2021.reset_index()
sc_df_2022 = sc_df_2022.reset_index()
sc_df_2023 = sc_df_2023.reset_index()

# %%
new_sc_df = sc_df_2021.append(sc_df_2022)
new_sc_df = new_sc_df.append(sc_df_2023)
new_sc_df = new_sc_df.reset_index()
new_sc_df = new_sc_df.drop(columns = ['index', 'level_0'])
new_sc_df
# Out:
#      First Name      Last Name                     Address  \
# 0       Jessica        Crafton          5105 mill creek rd
# 1       Juleigh       Gallaway               115 Griggs rd
# 2        Rachel  Blankenbecler         2040 Zelkova Drive
# 3         Megan        Ferrell      1208 Hammond carnes Rd
# 4        Sophia         Gibson   3499 North Rocky River Rd
# ...         ...            ...                         ...
# 1352      Janet        Krewson           14 Sawtooth Court
# 1353     Linda    Ange Ambrose  231 Ridgeland Lakes Drive
# 1354     Tyisha        Sumpter             163 trask pkwy
# 1355     Melody         Worley        3 Lindsey Hill Trail
# 1356   Madelynn        Poeggel         9825 English elm st
#
#                     City State    Zip License Code  License Number  \
# 0                 clover    SC  28012            C         73450.0
# 1                 Clover    SC  28056            C         67254.0
# ...

# %%
del nc_df
del sc_df

# %%
nc_df = new_nc_df
sc_df = new_sc_df

# %%
nc_df['Full Address'] = nc_df['Address']  + ' ' + nc_df['City'] + ' ' + nc_df['State']
sc_df['Full Address'] = sc_df['Address']  + ' ' + sc_df['City'] + ' ' + sc_df['State']

# %%
nc_df
# Out:
#          First Name Last Name                   Address         City State  \
# 0      Huong Nguyen      Dinh           9505 SEAMILL RD    CHARLOTTE    NC
# 1             Corey  Williams       120 Applecross Dr.   Franklinton    NC
# 2               Kim    Hawley    525 Christmas tree rd          Dunn    NC
# 3             Shara     Owens          PSC 103 Box 2527      APO, AE    NC
# 4              Emma   Patrick  2039 E Hudson Blvd Apt H     Gastonia    NC
# ...             ...       ...                       ...          ...   ...
# 52926         Suong      Veng          222 ROANOKE ROAD     FLETCHER    NC
# 52927        Silvia     Gallo       5305 Bakers Mill RD       Durham    NC
# 52928         selam    yosief  7701 creekridge rd #1003   charlotte     NC
# 52929         Emily    Barnes          676 Harris St NW      Concord    NC
# 52930        Jackie    Kramek      20080 Hosmer mine ct   Foresthill    NC
#
#           Zip License Code  License Number Expiration Date  \
# ...

# %%
from googlemaps import Client as GoogleMaps
gmaps = GoogleMaps('AIzaSyAgPOy0qY-0IRWKJhAzbw9XaKI_YhkecD0')

# %%
sc_df['Latitude'] = ""
sc_df['Longitude'] = ""
sc_lat = []
sc_lng = []
sc_addresses = sc_df['Full Address'].tolist()

# %%
sc_addresses
# Out:
# ['5105 mill creek rd clover SC',
#  '115 Griggs rd Clover SC',
#  '2040 Zelkova Drive  Indian Land SC',
#  '1208 Hammond carnes Rd Lancaster SC',
#  '3499 North Rocky River Rd Lancaster SC',
#  '1735 Lillywood Lane Indian Land SC',
#  '1855 Liliian Lane Fort Mill SC',
#  '604 lakeview landing road indian land SC',
#  '2587 Kendlewood Dr Lancaster SC',
#  '108 W Jefferson St York SC',
#  '6253 cloverdale drive Fort mill SC',
#  '2165 REYNOLDS RIDGE LANE apt 206 FORT MILL SC',
#  '1953 Brady Rd Lancaster SC',
#  '615 E Cheval Dr Fort Mill SC',
#  '1101 Waterlily Dr Fortmill SC',
#  '2820 Birkhill Lane Fort Mill SC',
#  '618 Andover Lane Tega Cay SC',
#  '2039 Saxon place drive fortmill SC',
#  '137 Bearwood Ln Fort Mill SC',
#  '106 River Wood Drive Fort Mill SC',
#  '7677 Newberry Rd Winnsboro SC',
#  '2003 Ebenezer Rd Rock Hill SC',
#  'P O Box 11366 Rock Hill SC',
#  '10 Longleaf Road Lake Wylie SC',
#  '2021 arboretum road rock hill SC',
#  '27095 cove lane Fort mill SC',
# ...

# %%
import asyncio
import time

# %%
import nest_asyncio
nest_asyncio.apply()
import aiohttp
import json

# %% [raw]
# async def myCoroutine():
#     for x in range(len(sc_df)):
#         geocode_result = gmaps.geocode(sc_df['Full Address'][x])
# #         await asyncio.sleep(1)
#         sc_df['Latitude'][x] = geocode_result[0]['geometry']['location'] ['lat']
# #         await asyncio.sleep(1)
#         sc_df['Longitude'][x] = geocode_result[0]['geometry']['location']['lng']
# #         await asyncio.sleep(1)

# %% [raw]
# if __name__ == '__main__':
#     loop = asyncio.get_event_loop()
# #     tasks = (myCoroutine(x) for x in enumerate(sc_addresses))
#     loop.run_until_complete(myCoroutine())
# asyncio.run(myCoroutine())

# %% [raw]
# sc_df

# %% [raw]
# nc_df['Latitude'] = ""
# nc_df['Longitude'] = ""
# nc_lat = []
# nc_lng = []
# nc_addresses = nc_df['Full Address'].tolist()

# %% [raw]
# async def myCoroutine():
#     for x in range(len(nc_df)):
#         geocode_result = gmaps.geocode(nc_df['Full Address'][x])
# #         await asyncio.sleep(1)
#         nc_df['Latitude'][x] = geocode_result[0]['geometry']['location'] ['lat']
# #         await asyncio.sleep(1)
#         nc_df['Longitude'][x] = geocode_result[0]['geometry']['location']['lng']
# #         await asyncio.sleep(1)

# %% [raw]
# if __name__ == '__main__':
#     loop = asyncio.get_event_loop()
# #     tasks = (myCoroutine(x) for x in enumerate(nc_addresses))
#     loop.run_until_complete(myCoroutine())
# asyncio.run(myCoroutine())

# %%
nc_df
# Out:
#          First Name Last Name                   Address         City State  \
# 0      Huong Nguyen      Dinh           9505 SEAMILL RD    CHARLOTTE    NC
# 1             Corey  Williams       120 Applecross Dr.   Franklinton    NC
# 2               Kim    Hawley    525 Christmas tree rd          Dunn    NC
# 3             Shara     Owens          PSC 103 Box 2527      APO, AE    NC
# 4              Emma   Patrick  2039 E Hudson Blvd Apt H     Gastonia    NC
# ...             ...       ...                       ...          ...   ...
# 52926         Suong      Veng          222 ROANOKE ROAD     FLETCHER    NC
# 52927        Silvia     Gallo       5305 Bakers Mill RD       Durham    NC
# 52928         selam    yosief  7701 creekridge rd #1003   charlotte     NC
# 52929         Emily    Barnes          676 Harris St NW      Concord    NC
# 52930        Jackie    Kramek      20080 Hosmer mine ct   Foresthill    NC
#
#           Zip License Code  License Number Expiration Date  \
# ...

# %% [raw]
# sc_df.to_csv('south_carolina.csv', index=False, header=True)

# %% [raw]
# for x in range(len(nc_df)):
#     try:
#         time.sleep(1) #to add delay in case of large DFs
#         geocode_result = gmaps.geocode(nc_df['Full Address'][x])
#         nc_df['Latitude'][x] = geocode_result[0]['geometry']['location'] ['lat']
#         nc_df['Longitude'][x] = geocode_result[0]['geometry']['location']['lng']
#     except:
#         print('Nope')

# %% [raw]
# import geopy
# from geopy import GoogleV3
# geolocator = GoogleV3(api_key='AIzaSyAgPOy0qY-0IRWKJhAzbw9XaKI_YhkecD0')

# %% [raw]
# nc_df["loc"] = nc_df["Full Address"].apply(geolocator.geocode)

# %% [raw]
# nc_df["point"]= nc_df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)

# %% [raw]
# nc_df[['Latitude', 'Longitude', 'Altitude']] = pd.DataFrame(nc_df['point'].to_list(), index=nc_df.index)

# %% [raw]
# nc_df = nc_df.drop(columns=['loc', 'point', 'Altitude'])

# %% [raw]
# nc_df

# %%
locations = sc_df[["Latitude", "Longitude"]].astype(float)
locations_2 = nc_df[["Latitude", "Longitude"]].astype(float)

# %% [raw]
# sc_df["loc"] = sc_df["Full Address"].apply(geolocator.geocode)
# sc_df["point"]= sc_df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)
# sc_df[['Latitude', 'Longitude', 'Altitude']] = pd.DataFrame(sc_df['point'].to_list(), index=sc_df.index)

# %% [raw]
# sc_df = sc_df.drop(columns=['loc', 'point', 'Altitude'])

# %% [raw]
# sc_df

# %%
import gmaps
gmaps.configure(api_key='AIzaSyAgPOy0qY-0IRWKJhAzbw9XaKI_YhkecD0')

# %%
fig = gmaps.figure()

fig.add_layer(gmaps.heatmap_layer(locations))


fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
sc_df.to_csv('south_carolina.csv', index=False, header=True)

# %%
nc_df.to_csv('north_carolina.csv', index=False, header=True)
